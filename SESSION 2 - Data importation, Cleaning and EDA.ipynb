# %% [markdown]
# # **Data Importation**

# %% [markdown]
# ## Loading libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("GSSsubset.csv")
data.head()
# Out:
#    id     sex       degree    income   marital  age  height  weight  hrswrk
# 0   1    MALE     BACHELOR  60967.50  DIVORCED   53      72     190      60
# 1   2  FEMALE     BACHELOR  60967.50   MARRIED   26      60      97      40
# 2   4  FEMALE     BACHELOR  10161.25   MARRIED   56      68     160      20
# 3  14  FEMALE  HIGH SCHOOL  17551.25   MARRIED   40      65     156      37
# 4  16    MALE  HIGH SCHOOL  17551.25   MARRIED   56      66     210       6

# %% [markdown]
# # Examination of data set

# %%
data.tail(10)
# Out:
#        id     sex       degree    income        marital  age  height  weight  \
# 984  2523    MALE     BACHELOR  24017.50        MARRIED   54      72     195
# 985  2524    MALE     BACHELOR  33255.00        MARRIED   49      70     195
# 986  2525  FEMALE     BACHELOR  33255.00        MARRIED   53      64     150
# 987  2526    MALE     BACHELOR  40645.00        MARRIED   52      72     200
# 988  2530    MALE  HIGH SCHOOL  33255.00        MARRIED   62      71     215
# 989  2531    MALE  HIGH SCHOOL   1478.00  NEVER MARRIED   40      71     230
# 990  2535    MALE  HIGH SCHOOL  33255.00       DIVORCED   56      72     195
# 991  2536    MALE  HIGH SCHOOL   8313.75  NEVER MARRIED   24      68     145
# 992  2537    MALE  HIGH SCHOOL  27712.50  NEVER MARRIED   27      68     180
# 993  2538  FEMALE  HIGH SCHOOL  15703.75        WIDOWED   71      63     140
#
#      hrswrk
# 984      40
# 985      40
# 986      40
# 987      50
# 988      48
# 989      48
# 990      46
# 991      40
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       994 non-null    int64
#  1   sex      994 non-null    object
#  2   degree   994 non-null    object
#  3   income   994 non-null    float64
#  4   marital  994 non-null    object
#  5   age      994 non-null    int64
#  6   height   994 non-null    int64
#  7   weight   994 non-null    int64
#  8   hrswrk   994 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 70.0+ KB

# %% [markdown]
# ## **Data cleaning and Preprocessing**
#
# **Handling missing values**
#
# **Check for missing values in every column**

# %%
miss_values=data.isnull().sum()
miss_values
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %%
data.dropna(inplace=True)
missing_values=data.isnull().sum()
missing_values
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %% [markdown]
# **Remove rows with missing values**

# %% [markdown]
# **Identification of outliers using boxplots**

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="income")
plt.title("boxplot of income distribution")
plt.ylabel("income")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="income")
plt.title("boxplot of income distribution")
plt.ylabel("income")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="income")
plt.title("boxplot of income distribution")
plt.ylabel("income")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="height")
plt.title("boxplot of height distribution")
plt.ylabel("height")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="hrswrk")
plt.title("boxplot of hrswrk distribution")
plt.ylabel("hrswrk")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="age")
plt.title("boxplot ofage distribution")
plt.ylabel("age")
plt.show()

# %% [markdown]
# ## Box plot for all numerical variables

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.xticks(rotation=45) # Rotate x-axis labels if needed
plt.title("Box Plot for All Numerical Variables")
plt.show()

# %% [markdown]
# ## 1.Removing outliers
# ### 1.1.5 Inter-Quartile Rule

# %%
Q1 = data["income"].quantile(0.25)
Q3 = data["income"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

data = data[(data["income"] >= lower_bound) & (data["income"] <= upper_bound)]
print("outlier removed successfully")
# Out:
# outlier removed successfully

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="income", color='blue')
plt.title("boxplot of income distribution")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="income")
plt.title("boxplot of income distribution")
plt.ylabel("income")
plt.show()

# %% [markdown]
# # **Summary Statistics**

# %%
summary_statistics=data.describe()
summary_statistics
# Out:
#                 id        income         age      height      weight  \
# count   933.000000    933.000000  933.000000  933.000000  933.000000
# mean   1285.545552  29813.263934   43.981779   67.251876  180.096463
# std     731.089443  20731.468182   13.142365    4.028041   41.563687
# min       1.000000    369.500000   19.000000   57.000000   90.000000
# 25%     681.000000  15703.750000   33.000000   64.000000  150.000000
# 50%    1272.000000  24017.500000   43.000000   67.000000  175.000000
# 75%    1923.000000  40645.000000   54.000000   70.000000  202.000000
# max    2538.000000  88680.000000   79.000000   78.000000  410.000000
#
#            hrswrk
# count  933.000000
# mean    41.840300
# std     13.918648
# min      1.000000
# 25%     37.000000
# 50%     40.000000
# 75%     50.000000
# max     89.000000

# %%
summary_statistics=data.drop(columns=["id"]).describe()
summary_statistics
# Out:
#              income         age      height      weight      hrswrk
# count    933.000000  933.000000  933.000000  933.000000  933.000000
# mean   29813.263934   43.981779   67.251876  180.096463   41.840300
# std    20731.468182   13.142365    4.028041   41.563687   13.918648
# min      369.500000   19.000000   57.000000   90.000000    1.000000
# 25%    15703.750000   33.000000   64.000000  150.000000   37.000000
# 50%    24017.500000   43.000000   67.000000  175.000000   40.000000
# 75%    40645.000000   54.000000   70.000000  202.000000   50.000000
# max    88680.000000   79.000000   78.000000  410.000000   89.000000

# %% [markdown]
# # Summary Statistics for Categorical Variables

# %%
categorical_summary=data.describe(include=["O"])
categorical_summary
# Out:
#            sex       degree  marital
# count      933          933      933
# unique       2            5        5
# top     FEMALE  HIGH SCHOOL  MARRIED
# freq       478          477      436

# %% [markdown]
# ## Data Visualization
#
# ### Histogram

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=data,x="income",bins=15,kde=True,color="yellow")
plt.xlabel("income")
plt.ylabel("frequency")
plt.title("histogram of income distribution")
#plt.minorticks_on()
plt.minorticks_on()  # enable minor ticks

plt.grid(which='minor', linestyle=':', linewidth=0.5)
plt.grid(True)
plt.show()

# %% [markdown]
# # Box plot of income across degree

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=data,x="degree",y="income",hue="degree",palette="Set1")
plt.xticks(rotation=45)
plt.xlabel("degree")
plt.ylabel("income")
plt.title("boxplot of income across education levels")
plt.show()

# %% [markdown]
# ## Scatter Plot of Age and Income
#
# ### Assistant

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

sns.scatterplot(data=data, x='age', y='income', color='blue', alpha=0.6)

plt.xlabel("Age")
plt.ylabel("income")

plt.title("Scatter Plot of Age vs. Income")

plt.show()

# %% [markdown]
# #### **Add the Line of Best Fit to the Scatter Plot**

# %%
#install library scipy
#!pip install scipy

# %% [markdown]
# ### Assistant

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import linregress

plt.figure(figsize=(7, 5))
sns.regplot(x="age", y="income", data=data, scatter_kws={'color':'blue'}, line_kws={'color':'red'})

plt.title("Scatter Plot with Line of Best Fit")
plt.xlabel("Years of Experience")
plt.ylabel("Salary ($)")

plt.show()

# %% [markdown]
# ### Assistant

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import linregress
# Remove missing values
df_clean = data[['age', 'income']].dropna()
# Performing regression
slope, intercept, r_value, p_value, std_err = linregress(df_clean['age'], df_clean['income'])

plt.figure(figsize=(8, 5))

sns.scatterplot(x=df_clean['age'], y=df_clean['income'], color='blue', alpha=0.6, label="Data Points")

x_vals= np.linspace(df_clean['age'].min(), df_clean['age'].max(), 100)

y_vals = slope * x_vals + intercept

plt.plot(x_vals, y_vals, color='red', label="Best Fit Line", linewidth=2)

equation_text = f"y = {slope:.2f}x + {intercept:.2f}"

plt.text(df_clean['age'].min() + 2, df_clean['income'].max() - 5000, equation_text,
         fontsize=12, color='red', bbox=dict(facecolor='white', alpha=0.5))

plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Scatter Plot of Age vs. Income with Best Fit Line")

plt.legend()

plt.show()

# %% [markdown]
# ## **Homework**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_excel("data.xlsx")
data.head()
# Out:
#    ID   Age  Income_USD  Education_Years  Work_Experience  \
# 0   1  56.0         NaN              9.0              9.0
# 1   2  46.0    44250.15             19.0             39.0
# 2   3  32.0    43062.10             17.0             37.0
# 3   4  60.0    33312.54             20.0              5.0
# 4   5  25.0    63008.44             13.0              7.0
#
#    Customer_Satisfaction  Monthly_Spending  gender
# 0                    NaN            849.47    male
# 1                    4.0           1215.06  female
# 2                    7.0           1092.33    male
# 3                    3.0           1165.54  female
# 4                    2.0           1128.40  female

# %%
data.tail(5)
# Out:
#       ID   Age  Income_USD  Education_Years  Work_Experience  \
# 295  296  52.0    66105.23             18.0              6.0
# 296  297  33.0    51140.72             18.0              NaN
# 297  298  58.0    55294.40             12.0              7.0
# 298  299  53.0    59241.60             11.0             22.0
# 299  300  50.0    42069.14             18.0             28.0
#
#      Customer_Satisfaction  Monthly_Spending gender
# 295                    1.0            559.59   male
# 296                   10.0           2062.30   male
# 297                    8.0            747.42   male
# 298                    2.0           1534.53   male
# 299                    1.0               NaN   male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     300 non-null    int64
#  1   Age                    290 non-null    float64
#  2   Income_USD             290 non-null    float64
#  3   Education_Years        290 non-null    float64
#  4   Work_Experience        290 non-null    float64
#  5   Customer_Satisfaction  290 non-null    float64
#  6   Monthly_Spending       290 non-null    float64
#  7   gender                 295 non-null    object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 18.9+ KB

# %% [markdown]
# ## **Data Cleaning and Preprocessing**
#
# #### **Handling Missing Values**
#
# #### Check for missing values

# %%
miss_values=data.isnull().sum()
miss_values
# Out:
# ID                        0
# Age                      10
# Income_USD               10
# Education_Years          10
# Work_Experience          10
# Customer_Satisfaction    10
# Monthly_Spending         10
# gender                    5
# dtype: int64

# %%
data.dropna(inplace=True)
missing_values=data.isnull().sum()
missing_values
# Out:
# ID                       0
# Age                      0
# Income_USD               0
# Education_Years          0
# Work_Experience          0
# Customer_Satisfaction    0
# Monthly_Spending         0
# gender                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246 entries, 1 to 298
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     246 non-null    int64
#  1   Age                    246 non-null    float64
#  2   Income_USD             246 non-null    float64
#  3   Education_Years        246 non-null    float64
#  4   Work_Experience        246 non-null    float64
#  5   Customer_Satisfaction  246 non-null    float64
#  6   Monthly_Spending       246 non-null    float64
#  7   gender                 246 non-null    object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
miss_values=data.isnull().sum()
miss_values
# Out:
# ID                       0
# Age                      0
# Income_USD               0
# Education_Years          0
# Work_Experience          0
# Customer_Satisfaction    0
# Monthly_Spending         0
# gender                   0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.xticks(rotation=45) # Rotate x-axis labels if needed
plt.title("Box Plot for All Numerical Variables")
plt.show()

# %%
plt.figure(figsize= (5, 5))
sns.boxplot(data= data, y = "Income_USD")
plt.title("boxplot of income distribution")
plt.ylabel("income")
plt.show()

# %%
plt.figure(figsize= (5, 5))
sns.boxplot(data= data, y = "Monthly_Spending")
plt.title("boxplot of monthly distribution")
plt.ylabel("monthly")
plt.show()

# %%
Q1 = data["Income_USD"].quantile(0.25)
Q3 = data["Income_USD"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

data = data[(data["Income_USD"] >= lower_bound) & (data["Income_USD"] <= upper_bound)]

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="Income_USD")
plt.title("boxplot of Income distribution")
plt.ylabel("Income")
plt.show()

# %%
Q1 = data["Monthly_Spending"].quantile(0.25)
Q3 = data["Monthly_Spending"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

data = data[(data["Monthly_Spending"] >= lower_bound) & (data["Monthly_Spending"] <= upper_bound)]

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=data,y="Monthly_Spending")
plt.title("boxplot of Monthly distribution")
plt.ylabel("Monthly")
plt.show()

# %%
summary_statistics=data.describe()
summary_statistics
# Out:
#                ID         Age    Income_USD  Education_Years  Work_Experience  \
# count  242.000000  242.000000    242.000000       242.000000       242.000000
# mean   154.037190   40.450413  49532.169669        13.834711        20.830579
# std     85.054697   13.297413  15703.590732         3.597710        11.319951
# min      2.000000   18.000000  10868.180000         8.000000         0.000000
# 25%     84.500000   29.000000  39023.625000        11.000000        11.000000
# 50%    156.500000   41.500000  49212.850000        14.000000        22.000000
# 75%    227.250000   52.000000  61775.455000        17.000000        30.750000
# max    299.000000   64.000000  84100.180000        20.000000        39.000000
#
#        Customer_Satisfaction  Monthly_Spending
# count             242.000000        242.000000
# mean                5.396694       1211.237149
# std                 2.932093        380.629077
# min                 1.000000        300.360000
# ...

# %%
summary_statistics=data.drop(columns = ["ID"]).describe()
summary_statistics
# Out:
#               Age    Income_USD  Education_Years  Work_Experience  \
# count  242.000000    242.000000       242.000000       242.000000
# mean    40.450413  49532.169669        13.834711        20.830579
# std     13.297413  15703.590732         3.597710        11.319951
# min     18.000000  10868.180000         8.000000         0.000000
# 25%     29.000000  39023.625000        11.000000        11.000000
# 50%     41.500000  49212.850000        14.000000        22.000000
# 75%     52.000000  61775.455000        17.000000        30.750000
# max     64.000000  84100.180000        20.000000        39.000000
#
#        Customer_Satisfaction  Monthly_Spending
# count             242.000000        242.000000
# mean                5.396694       1211.237149
# std                 2.932093        380.629077
# min                 1.000000        300.360000
# 25%                 3.000000        921.207500
# 50%                 5.000000       1229.635000
# ...

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=data,x="Income_USD",bins=15,kde=True,color="blue")
plt.xlabel("Income")
plt.ylabel("frequency")
plt.title("histogram of Income distribution")
#plt.minorticks_on()
plt.minorticks_on()  # enable minor ticks

plt.grid(which='minor', linestyle=':', linewidth=0.5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=data,x="Monthly_Spending",bins=15,kde=True,color="green")
plt.xlabel("monthly")
plt.ylabel("frequency")
plt.title("histogram of monthly distribution")
#plt.minorticks_on()
plt.minorticks_on()  # enable minor ticks

plt.grid(which='minor', linestyle=':', linewidth=0.5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=data,x="Age",bins=15,kde=True,color="pink")
plt.xlabel("age")
plt.ylabel("frequency")
plt.title("histogram of age distribution")
#plt.minorticks_on()
plt.minorticks_on()  # enable minor ticks

plt.grid(which='minor', linestyle=':', linewidth=0.5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.histplot(data=data,x="Education_Years",bins=15,kde=True,color="pink")
plt.xlabel("Education")
plt.ylabel("frequency")
plt.title("histogram of Education distribution")
#plt.minorticks_on()
plt.minorticks_on()  # enable minor ticks

plt.grid(which='minor', linestyle=':', linewidth=0.5)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=data,x="Education_Years",y="Income_USD",hue="Education_Years",palette="Set2")
plt.xticks(rotation=45)
plt.xlabel("Education")
plt.ylabel("Income")
plt.title("boxplot of education across income")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

sns.scatterplot(data=data, x='Income_USD', y='Monthly_Spending', color='blue', alpha=0.6)

plt.xlabel("income")
plt.ylabel("monthly")

plt.title("Scatter Plot of income vs. monthly")

plt.show()
